# %% [markdown]
# ### Sleep Health Living Analysis Report
#
# 1. ## Introduction
# This report presents the findings of an analysis conducted on a dataset related to sleep health living. The analysis involved cleaning the data, conducting univariate analysis using Seaborn plots in Python, and utilizing Tableau for visualization. The objective was to gain insights into sleep patterns, identify potential sleep disorders, and understand their correlation with various factors such as age, occupation, stress levels, physical activities, and blood pressure.
#
# 2. ## Data Cleaning
# To ensure the accuracy of the analysis, data cleaning was performed, addressing missing data, outliers, and invalid entries. This step laid the foundation for a robust and reliable examination of sleep-related variables.
#
# 3. ## Univariate Analysis
# Univariate analysis was conducted using Seaborn plots in Python. This allowed for a detailed exploration of individual variables, including sleep duration, Blood pressure, Physical activities, Daily steps and sleep quality, providing a comprehensive overview of the dataset.
#
# 4. ## Multivariate Analysis
# While the initial analysis involved univariate exploration, the multivariate analysis aimed to identify correlations and patterns among multiple variables. However, it is noted that the multivariate analysis did not reveal significant correlations among the variables in this particular dataset.
#
# 5. ## Key Performance Indicators (KPIs) and Additional Field
# In the absence of strong correlations from the multivariate analysis, a new field of Key Performance Indicators (KPIs) was introduced during the visualization stage in Tableau. This field included Sleep Disorder Rate, Sleep Disorder Count, No Disorder Count, and Age Group, providing a summarized view of key metrics derived from the dataset.
#
# 6. ## Observations
# ## Sleep Disorder by Age
# Visualizations revealed a higher prevalence of sleep disorders among females compared to males across different age groups.
#
# ## Sleep Disorder by Occupation
# Occupations such as Nurses, Teachers, and Salespersons exhibited higher percentages of sleep disorders (41%, 20%, and 19%, respectively), while Doctors, Engineers, Lawyers, Software Engineers, and Scientists had lower percentages.
#
# ## Sleep Disorder by Age Distribution
# Participants aged 27 to 59 were observed to have sleep disorders, with peaks at age 44, 43, and 50.
#
# ## Stress Level by Occupation
# Differences in stress levels were observed across various occupations, with Doctors and Nurses experiencing higher stress levels compared to Salespersons, Lawyers, Teachers, Accountants, Engineers, and other professions. Doctors and nurses exhibit the highest stress levels (8), followed by salespeople (7), lawyers (5), and teachers/accountants (4) with engineers having the lowest stress (3).
#
# ## Sleep Disorder by Physical Activities
# Individuals with no sleep disorder engage in the highest levels of physical activity, followed by those with sleep apnea, and those with insomnia displaying the lowest activity levels.
#
# ## Sleep Disorder by Age Group
# Age groups 20-30 and 31-40 show higher representation of individuals without sleep disorders, while 41-50 leans towards insomnia and 51-60 towards sleep apnea.
#
# ## Sleep Disorder by Blood Pressure
# Among individuals with normal blood pressure, few have sleep disorders, with sleep apnea being more prevalent than insomnia. Within the prehypertensive range, insomnia is more common than sleep apnea, while the hypertensive group has the highest proportion of sleep apnea cases, followed by insomnia and then individuals without sleep disorders.
#
# 7. Conclusion
# The analysis, combining univariate exploration, multivariate analysis, and Tableau visualizations, provides a comprehensive understanding of sleep health factors. While multivariate analysis did not reveal significant correlations, the visualizations in Tableau allowed for insightful observations and the creation of key performance indicators.
#
# 8. Recommendations
# Continue collecting diverse data to further explore potential correlations.
# Utilize Tableau for effective visualization and interpretation of complex datasets.
# Consider additional factors or variables that may contribute to sleep health.

# %%
###Import all necessaery libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
original_df = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# ##Data cleaning
#     ##handling missing data;
#     ## find outliers;
#     ## handle invalid data

# %%
##Handling missing data
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df = original_df.copy()
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
miss_value_percentage = (df['Sleep Disorder'].isnull().sum()/len(df)*100)
miss_value_percentage
# Out:
# 58.55614973262032

# %%
df['Sleep Disorder'].mode()
# Out:
# 0    Sleep Apnea
# Name: Sleep Disorder, dtype: object

# %%
value_counts = df['Sleep Disorder'].value_counts()
value_counts
# Out:
# Sleep Disorder
# Sleep Apnea    78
# Insomnia       77
# Name: count, dtype: int64

# %%
## treating the missing values
df.replace(np.nan, 'No_disorder', inplace=True)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200    No_disorder
# 1           125/80          75        10000    No_disorder
# 2           125/80          75        10000    No_disorder
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
value_counts = df['Sleep Disorder'].value_counts()
value_counts
# Out:
# Sleep Disorder
# No_disorder    219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64

# %% [markdown]
# Handle invalid data

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
print(f"Sleep Disorder: {df['Sleep Disorder'].unique()}")
print(f"Gender: {df['Gender'].unique()}")
print(f"Occupation: {df['Occupation'].unique()}")
print(f"BMI Category: {df['BMI Category'].unique()}")
# Out:
# Sleep Disorder: ['No_disorder' 'Sleep Apnea' 'Insomnia']
# Gender: ['Male' 'Female']
# Occupation: ['Software Engineer' 'Doctor' 'Sales Representative' 'Teacher' 'Nurse'
#  'Engineer' 'Accountant' 'Scientist' 'Lawyer' 'Salesperson' 'Manager']
# BMI Category: ['Overweight' 'Normal' 'Obese']

# %%
## Treat the inconsitency in the data quality of the dataset by replacing Normal weight with Normal##
df['BMI Category'].replace('Normal Weight', 'Normal', inplace= True)
print(f"Sleep Disorder: {df['BMI Category'].unique()}")
# Out:
# Sleep Disorder: ['Overweight' 'Normal' 'Obese']

# %%
df['BMI Category'].unique()
# Out:
# array(['Overweight', 'Normal', 'Obese'], dtype=object)

# %%
##check duplicate data
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 369    False
# 370    False
# 371    False
# 372    False
# 373    False
# Length: 374, dtype: bool

# %%
##check for outliers
import seaborn as sns

# %%
sns.boxplot(data=df)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Person ID'),
#   Text(1, 0, 'Age'),
#   Text(2, 0, 'Sleep Duration'),
#   Text(3, 0, 'Quality of Sleep'),
#   Text(4, 0, 'Physical Activity Level'),
#   Text(5, 0, 'Stress Level'),
#   Text(6, 0, 'Heart Rate'),
#   Text(7, 0, 'Daily Steps')])

# %% [markdown]
# EDA

# %%
## CHECKING THE DISTRIBUTION OF THE DATA##
df.shape
df.head()
df.tail()
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
## value counts
print(f"Sleep disorder: {df['Sleep Disorder'].value_counts()}")
print(f"BMI: {df['BMI Category'].value_counts()}")
print(f"Gender: {df['Gender'].value_counts()}")
print(f"Occupation: {df['Occupation'].value_counts()}")
# Out:
# Sleep disorder: Sleep Disorder
# No_disorder    219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64
# BMI: BMI Category
# Normal        216
# Overweight    148
# Obese          10
# Name: count, dtype: int64
# Gender: Gender
# Male      189
# Female    185
# Name: count, dtype: int64
# Occupation: Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
Sleep_disorder= df['Sleep Disorder'].unique()
Sleep_disorder
# Out:
# array([None, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
 #univariate analysis
# Set the style for seaborn plots
sns.set(style="whitegrid")

# Loop through each column and create univariate visualizations
for column in df.columns:
    plt.figure(figsize=(8, 5))
    
    # For numerical columns, create a histogram
    if df[column].dtype in ['int64', 'float64']:
        sns.histplot(df[column], kde=True, color='skyblue')
        plt.title(f'Univariate Analysis - {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
    
    # For categorical columns, create a countplot
    elif df[column].dtype == 'object':
        sns.countplot(data=df, x=column, palette='Set2')
        plt.title(f'Univariate Analysis - {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
    
    
    # For boolean columns, create a countplot
    elif df[column].dtype == 'bool':
        sns.countplot(data=df, x=column, palette='Set2')
        plt.title(f'Univariate Analysis - {column}')
        plt.xlabel(column)
        plt.ylabel('Count')

    plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23608\4056290975.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='Set2')
# C:\Users\user\AppData\Local\Temp\ipykernel_23608\4056290975.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='Set2')
# C:\Users\user\AppData\Local\Temp\ipykernel_23608\4056290975.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='Set2')
# C:\Users\user\AppData\Local\Temp\ipykernel_23608\4056290975.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='Set2')
# C:\Users\user\AppData\Local\Temp\ipykernel_23608\4056290975.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='Set2')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# BIVARIANT ANALYSIS

# %%
# Set the style for seaborn plots
sns.set(style="whitegrid")

# Specify a custom color palette with color names
custom_palette = {'Insomnia': 'orange', 'Sleep Apnea': 'red', 'No_disorder': 'blue'}

# Scatter plot for two numerical columns
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Age', y='Sleep Duration', hue='Sleep Disorder', palette=custom_palette)
plt.title('Bivariate Analysis - Scatter Plot')
plt.xlabel('Age')
plt.ylabel('Sleep Duration')
plt.legend(title='Sleep Disorder')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Age', y='Sleep Duration', hue='Sleep Disorder', palette='Set2')
plt.title('Bivariate Analysis - Scatter Plot')
plt.xlabel('Quality of Sleep')
plt.ylabel('Sleep Duration')
plt.legend(title='Sleep Disorder')
plt.show()

# %%
#Set the style for seaborn plots
sns.set(style="whitegrid")

# Specify a custom color palette with color names
custom_palette = {'Insomnia': 'orange', 'Sleep Apnea': 'red', 'No_disorder': 'blue'}

# Use pairplot for bivariate analysis of multiple columns
sns.pairplot(df, hue='Sleep Disorder', palette=custom_palette, diag_kind='kde')
plt.suptitle('Pair Plot for Bivariate Analysis', y=1.02)
plt.show()

# %%
df.to_csv('cleaned_sleep_and_healthy.csv', index=False)

# %%
new= pd.read_csv('cleaned_sleep_and_healthy.csv')
new
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200    No_disorder
# 1           125/80          75        10000    No_disorder
# 2           125/80          75        10000    No_disorder
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openpyxl) (1.1.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df.to_excel('Cleaned_sleep_health_lifestyle.xlsx', index=False)
